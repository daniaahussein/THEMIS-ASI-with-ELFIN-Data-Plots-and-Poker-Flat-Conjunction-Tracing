# %%
from themis_plot_dataset_class import *
# example plot2
plot2 = ThemisPlotDataset("/Users/dhussein/Downloads/thd_l2_fgm_20131106_v01.cdf")
print(plot2)
plot2.plot_dataset("thd_fgl_btotal")
plot2.display_plot("mosaic_plots/themis_atha_2022_03_05_12_25_12_30_movie.mp4", "thd_fgl_btotal", "test_1200")
# Out:
# thd_fgm_fgs_quality
# thd_fgm_fgl_quality
# thd_fgm_fgh_quality
# thd_fgm_fge_quality
# thd_fgs_btotalQ
# thd_fgs_btotal
# thd_fgs_gseQ
# thd_fgs_gse
# thd_fgs_gsmQ
# thd_fgs_gsm
# thd_fgs_dslQ
# thd_fgs_dsl
# thd_fgs_compno
# thd_fgs_time
# thd_fgs_epoch0
# thd_fgs_epoch
# thd_fgl_btotalQ
# thd_fgl_btotal
# thd_fgl_gseQ
# thd_fgl_gse
# thd_fgl_gsmQ
# thd_fgl_gsm
# thd_fgl_dslQ
# thd_fgl_dsl
# thd_fgl_sslQ
# thd_fgl_ssl
# thd_fgl_compno
# thd_fgl_time
# thd_fgl_epoch0
# thd_fgl_epoch16
# thd_fgh_btotalQ
# thd_fgh_btotal
# thd_fgh_gseQ
# thd_fgh_gse
# thd_fgh_gsmQ
# thd_fgh_gsm
# thd_fgh_dslQ
# thd_fgh_dsl
# thd_fgh_sslQ
# thd_fgh_ssl
# thd_fgh_compno
# thd_fgh_time
# thd_fgh_epoch0
# thd_fgh_epoch16
# thd_fge_btotalQ
# thd_fge_btotal
# thd_fge_gseQ
# thd_fge_gse
# thd_fge_gsmQ
# thd_fge_gsm
# thd_fge_dslQ
# thd_fge_dsl
# thd_fge_sslQ
# thd_fge_ssl
# thd_fge_compno
# thd_fge_labl
# thd_fge_time
# thd_fge_epoch0
# thd_fge_epoch16
# Rep_xyz
# range_epoch
# thd_fgl_labl
# thd_fgh_labl
# ...
